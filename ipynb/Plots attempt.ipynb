# %% [markdown]
# First attempt at data viz of LA Tracking Results

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load up Data

path2CRT01 = '/home/csi20local/Downloads/Results - Re-do CT-CRT-01 (2).csv'
path2CRT02 = '/home/csi20local/Downloads/Results - CT-CRT-02 (3).csv'
path2CRT05 = '/home/csi20local/Downloads/Results - CT-CRT-05 (1).csv'
path2CRT06 = '/home/csi20local/Downloads/Results - CT-CRT-06 (1).csv'
path2CRT07 = '/home/csi20local/Downloads/Results - CT-CRT-07 (1).csv'
path2CRT08 = '/home/csi20local/Downloads/Results - CT-CRT-08 (1).csv'
path2CRT09 = '/home/csi20local/Downloads/Results - CT-CRT-09 (1).csv'
path2CRT12 = '/home/csi20local/Downloads/Results - CT-CRT-12 (1).csv'
path2CRT15 = '/home/csi20local/Downloads/Results - CT-CRT-15 (1).csv'
path2CRT16 = '/home/csi20local/Downloads/Results - CT-CRT-16 (1).csv'

# %%
df_CRT01 = pd.read_csv(path2CRT01, skiprows=14)
df_CRT01 = df_CRT01.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT01 = df_CRT01.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT01 = df_CRT01.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18'],
                         axis=1)

df_CRT02 = pd.read_csv(path2CRT02, skiprows=14)
df_CRT02 = df_CRT02.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT02 = df_CRT02.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT02 = df_CRT02.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT02.drop(df_CRT02.tail(4).index,inplace=True) # drop last n rows

df_CRT05 = pd.read_csv(path2CRT05, skiprows=14)
df_CRT05 = df_CRT05.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT05 = df_CRT05.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT05 = df_CRT05.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT05.drop(df_CRT05.tail(4).index,inplace=True) # drop last n rows

df_CRT06 = pd.read_csv(path2CRT06, skiprows=14)
df_CRT06 = df_CRT06.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT06 = df_CRT06.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT06 = df_CRT06.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT06.drop(df_CRT06.tail(4).index,inplace=True) # drop last n rows

df_CRT07 = pd.read_csv(path2CRT07, skiprows=14)
df_CRT07 = df_CRT07.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT07 = df_CRT07.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT07 = df_CRT07.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT07.drop(df_CRT07.tail(4).index,inplace=True) # drop last n rows

df_CRT08 = pd.read_csv(path2CRT08, skiprows=14)
df_CRT08 = df_CRT08.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT08 = df_CRT08.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT08 = df_CRT08.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT08.drop(df_CRT08.tail(4).index,inplace=True) # drop last n rows

df_CRT09 = pd.read_csv(path2CRT09, skiprows=14)
df_CRT09 = df_CRT09.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT09 = df_CRT09.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT09 = df_CRT09.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT09.drop(df_CRT09.tail(4).index,inplace=True) # drop last n rows

df_CRT12 = pd.read_csv(path2CRT12, skiprows=14)
df_CRT12 = df_CRT12.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT12 = df_CRT12.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT12 = df_CRT12.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT12.drop(df_CRT12.tail(4).index,inplace=True) # drop last n rows

df_CRT15 = pd.read_csv(path2CRT15, skiprows=14)
df_CRT15 = df_CRT15.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
df_CRT15 = df_CRT15.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT15 = df_CRT15.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT15.drop(df_CRT15.tail(4).index,inplace=True) # drop last n rows

df_CRT16 = pd.read_csv(path2CRT16, skiprows=14)
df_CRT16 = df_CRT16.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                          7:'1e-9', 8:'4e-10'})
df_CRT16 = df_CRT16.rename(columns={'Unnamed: 2': '9e-2', 'Unnamed: 3': '3e-2', 'Unnamed: 4': '9e-3', 
                                    'Unnamed: 5': '3e-3', 'Unnamed: 6': '9e-4', 'Unnamed: 7': '3e-4', 
                                    'Unnamed: 8': '0.00'})
df_CRT16 = df_CRT16.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
                          'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19'],
                         axis=1)
df_CRT16.drop(df_CRT16.tail(4).index,inplace=True) # drop last n rows

# %%
fig, ax = plt.subplots(figsize=(18,9), dpi=150)

array_CRT01 = df_CRT01.to_numpy()
array_CRT01 = array_CRT01.flatten()
#plt.boxplot(array_CRT01)

array_CRT02 = df_CRT02.to_numpy()
array_CRT02 = array_CRT02.flatten()
#plt.boxplot(array_CRT02)

array_CRT05 = df_CRT05.to_numpy()
array_CRT05 = array_CRT05.flatten()
#plt.boxplot(array_CRT05)

array_CRT06 = df_CRT06.to_numpy()
array_CRT06 = array_CRT06.flatten()
#plt.boxplot(array_CRT06)

array_CRT07 = df_CRT07.to_numpy()
array_CRT07 = array_CRT07.flatten()
#plt.boxplot(array_CRT07)

array_CRT08 = df_CRT08.to_numpy()
array_CRT08 = array_CRT08.flatten()
#plt.boxplot(array_CRT08)

array_CRT09 = df_CRT09.to_numpy()
array_CRT09 = array_CRT09.flatten()
#plt.boxplot(array_CRT09)

array_CRT12 = df_CRT12.to_numpy()
array_CRT12 = array_CRT12.flatten()
#plt.boxplot(array_CRT12)

array_CRT15 = df_CRT15.to_numpy()
array_CRT15 = array_CRT15.flatten()
#plt.boxplot(array_CRT15)

array_CRT16 = df_CRT16.to_numpy()
array_CRT16 = array_CRT16.flatten()
#plt.boxplot(array_CRT16)

data = [array_CRT01, array_CRT02, array_CRT05, array_CRT06, array_CRT07,
       array_CRT08, array_CRT09, array_CRT12, array_CRT15, array_CRT16]

ax.boxplot(data, whis=(0,100))

ax.set_ylim(0.4, 1.4)
ax.tick_params(labelsize=15)
ax.set_ylabel('Average Surface Distance [mm]', fontsize=20)
ax.set_xlabel('Case', fontsize=20)
# Out:
# Text(0.5, 0, 'Case')

# %%
df_CRT01_haus = pd.read_csv(path2CRT01, skiprows=4, skipfooter=10)
df_CRT01_haus = df_CRT01_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
                         axis=1)
df_CRT01_haus = df_CRT01_haus.rename(columns={'Unnamed: 12': '9e-2', 'Unnamed: 13': '3e-2', 'Unnamed: 14': '9e-3', 
                                    'Unnamed: 15': '3e-3', 'Unnamed: 16': '9e-4', 'Unnamed: 17': '3e-4', 
                                    'Unnamed: 18': '0.00'})
df_CRT01_haus = df_CRT01_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT02_haus = pd.read_csv(path2CRT02, skiprows=4, skipfooter=14)
df_CRT02_haus = df_CRT02_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT02_haus = df_CRT02_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT02_haus = df_CRT02_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT05_haus = pd.read_csv(path2CRT05, skiprows=4, skipfooter=14)
df_CRT05_haus = df_CRT05_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT05_haus = df_CRT05_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT05_haus = df_CRT05_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT06_haus = pd.read_csv(path2CRT06, skiprows=4, skipfooter=14)
df_CRT06_haus = df_CRT06_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT06_haus = df_CRT06_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT06_haus = df_CRT06_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT07_haus = pd.read_csv(path2CRT07, skiprows=4, skipfooter=14)
df_CRT07_haus = df_CRT07_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT07_haus = df_CRT07_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT07_haus = df_CRT07_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT08_haus = pd.read_csv(path2CRT08, skiprows=4, skipfooter=14)
df_CRT08_haus = df_CRT08_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT08_haus = df_CRT08_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT08_haus = df_CRT08_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT09_haus = pd.read_csv(path2CRT09, skiprows=4, skipfooter=14)
df_CRT09_haus = df_CRT09_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT09_haus = df_CRT09_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT09_haus = df_CRT09_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT12_haus = pd.read_csv(path2CRT12, skiprows=4, skipfooter=14)
df_CRT12_haus = df_CRT12_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT12_haus = df_CRT12_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT12_haus = df_CRT12_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT15_haus = pd.read_csv(path2CRT15, skiprows=4, skipfooter=14)
df_CRT15_haus = df_CRT15_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT15_haus = df_CRT15_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT15_haus = df_CRT15_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})

df_CRT16_haus = pd.read_csv(path2CRT16, skiprows=4, skipfooter=14)
df_CRT16_haus = df_CRT16_haus.drop(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
                          'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
                         axis=1)
df_CRT16_haus = df_CRT16_haus.rename(columns={'Unnamed: 13': '9e-2', 'Unnamed: 14': '3e-2', 'Unnamed: 15': '9e-3', 
                                    'Unnamed: 16': '3e-3', 'Unnamed: 17': '9e-4', 'Unnamed: 18': '3e-4', 
                                    'Unnamed: 19': '0.00'})
df_CRT16_haus = df_CRT16_haus.rename(index={0: '4e-6', 1:'1e-6', 2:'4e-7', 3:'1e-7', 4:'4e-8', 5:'1e-8', 6:'4e-9', 
                                  7:'1e-9', 8:'4e-10'})
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:11: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   # This is added back by InteractiveShellApp.init_path()
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:21: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# ...

# %%
fig, ax = plt.subplots(figsize=(18,9))

array_CRT01 = df_CRT01_haus.to_numpy()
array_CRT01 = array_CRT01.flatten()

array_CRT02 = df_CRT02_haus.to_numpy()
array_CRT02 = array_CRT02.flatten()

array_CRT05 = df_CRT05_haus.to_numpy()
array_CRT05 = array_CRT05.flatten()

array_CRT06 = df_CRT06_haus.to_numpy()
array_CRT06 = array_CRT06.flatten()

array_CRT07 = df_CRT07_haus.to_numpy()
array_CRT07 = array_CRT07.flatten()

array_CRT08 = df_CRT08_haus.to_numpy()
array_CRT08 = array_CRT08.flatten()

array_CRT09 = df_CRT09_haus.to_numpy()
array_CRT09 = array_CRT09.flatten()

array_CRT12 = df_CRT12_haus.to_numpy()
array_CRT12 = array_CRT12.flatten()

array_CRT15 = df_CRT15_haus.to_numpy()
array_CRT15 = array_CRT15.flatten()

array_CRT16 = df_CRT16_haus.to_numpy()
array_CRT16 = array_CRT16.flatten()

data = [array_CRT01, array_CRT02, array_CRT05, array_CRT06, array_CRT07,
       array_CRT08, array_CRT09, array_CRT12, array_CRT15, array_CRT16]

ax.boxplot(data, whis=(0,100))

ax.set_ylim(2, 12)
ax.tick_params(labelsize=15)
ax.set_ylabel('Directed Hausdorff Distance [mm]', fontsize=20)
ax.set_xlabel('Case', fontsize=20)
# Out:
# Text(0.5, 0, 'Case')

# %%
# Population optimisation errors

asd_pop = []
dhd_pop = []

# %%
for df in [df_CRT01, df_CRT02, df_CRT05, df_CRT06, df_CRT07,
           df_CRT08, df_CRT09, df_CRT12, df_CRT15, df_CRT16]:
    
    asd_pop.append(df['3e-3']['1e-6'])

# %%
for df in [df_CRT01_haus, df_CRT02_haus, df_CRT05_haus, df_CRT06_haus, df_CRT07_haus,
           df_CRT08_haus, df_CRT09_haus, df_CRT12_haus, df_CRT15_haus, df_CRT16_haus]:
    
    dhd_pop.append(df['3e-4']['1e-6'])

# %%
cases = list(np.arange(1,11,1))

# %%
max(asd_pop)
# Out:
# 1.011403769

# %%
asd_pop
# Out:
# [0.7661848726968961,
#  0.5966055272999999,
#  0.8642972749,
#  1.011403769,
#  0.9628047738,
#  0.7755538719,
#  0.5583970522999999,
#  0.67371282,
#  0.9349190411,
#  0.6655037679]

# %%
max(dhd_pop)
# Out:
# 8.663708253

# %%
dhd_pop
# Out:
# [4.892787533,
#  3.3299960960000003,
#  6.545395805,
#  8.663708253,
#  5.126842409,
#  3.331164667,
#  6.950691455,
#  5.00599814,
#  5.998467474,
#  6.40719396]

# %%
# LV optimisation errors

asd_LV = []
dhd_LV = []

# %%
for df in [df_CRT01, df_CRT02, df_CRT05, df_CRT06, df_CRT07,
           df_CRT08, df_CRT09, df_CRT12, df_CRT15, df_CRT16]:
    
    asd_LV.append(df['9e-3']['4e-7'])

# %%
for df in [df_CRT01_haus, df_CRT02_haus, df_CRT05_haus, df_CRT06_haus, df_CRT07_haus,
           df_CRT08_haus, df_CRT09_haus, df_CRT12_haus, df_CRT15_haus, df_CRT16_haus]:
    
    dhd_LV.append(df['9e-3']['4e-7'])

# %%
max(asd_LV)
# Out:
# 1.072724274

# %%
asd_LV
# Out:
# [0.7472549844379646,
#  0.6569769394,
#  0.9643762598000001,
#  1.072724274,
#  1.034159526,
#  0.7873622422,
#  0.6089430096,
#  0.6716549734999999,
#  1.037559645,
#  0.683035299]

# %%
dhd_LV
# Out:
# [4.351577227,
#  3.4177362760000003,
#  7.110912901,
#  8.208205047,
#  6.53677258,
#  3.860078932,
#  7.113455371000001,
#  4.996753117,
#  6.598660316,
#  6.6245646570000005]

# %%
# Case optimisation errors

asd_case = []
dhd_case = []

# %%
for df in [df_CRT01, df_CRT02, df_CRT05, df_CRT06, df_CRT07,
           df_CRT08, df_CRT09, df_CRT12, df_CRT15, df_CRT16]:
    
    asd_case.append(df['3e-3']['1e-6'])

# %%
for df in [df_CRT01_haus, df_CRT02_haus, df_CRT05_haus, df_CRT06_haus, df_CRT07_haus,
           df_CRT08_haus, df_CRT09_haus, df_CRT12_haus, df_CRT15_haus, df_CRT16_haus]:
    
    dhd_case.append(df['3e-4']['1e-6'])

# %%
min(asd_case)
# Out:
# 0.5583970522999999

# %%
min(dhd_case)
# Out:
# 3.3299960960000003

# %%
for i in range(0,10):
    print(asd_pop[i] - asd_LV[i])
# Out:
# 0.018929888258931493
# -0.06037141210000008
# -0.10007898490000011
# -0.06132050500000008
# -0.0713547522000001
# -0.011808370299999926
# -0.05054595730000011
# 0.002057846500000071
# -0.10264060389999996
# -0.017531531100000053

# %%
for i in range(0,10):
    print(dhd_pop[i] - dhd_LV[i])
# Out:
# 0.541210306
# -0.08774017999999995
# -0.5655170959999998
# 0.4555032059999995
# -1.409930171
# -0.528914265
# -0.16276391600000029
# 0.009245023000000074
# -0.6001928420000002
# -0.21737069700000067

# %%
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(18,6), dpi=150)

array_CRT01 = df_CRT01.to_numpy()
array_CRT01 = array_CRT01.flatten()
#plt.boxplot(array_CRT01)

array_CRT02 = df_CRT02.to_numpy()
array_CRT02 = array_CRT02.flatten()
#plt.boxplot(array_CRT02)

array_CRT05 = df_CRT05.to_numpy()
array_CRT05 = array_CRT05.flatten()
#plt.boxplot(array_CRT05)

array_CRT06 = df_CRT06.to_numpy()
array_CRT06 = array_CRT06.flatten()
#plt.boxplot(array_CRT06)

array_CRT07 = df_CRT07.to_numpy()
array_CRT07 = array_CRT07.flatten()
#plt.boxplot(array_CRT07)

array_CRT08 = df_CRT08.to_numpy()
array_CRT08 = array_CRT08.flatten()
#plt.boxplot(array_CRT08)

array_CRT09 = df_CRT09.to_numpy()
array_CRT09 = array_CRT09.flatten()
#plt.boxplot(array_CRT09)

array_CRT12 = df_CRT12.to_numpy()
array_CRT12 = array_CRT12.flatten()
#plt.boxplot(array_CRT12)

array_CRT15 = df_CRT15.to_numpy()
array_CRT15 = array_CRT15.flatten()
#plt.boxplot(array_CRT15)

array_CRT16 = df_CRT16.to_numpy()
array_CRT16 = array_CRT16.flatten()
#plt.boxplot(array_CRT16)

data = [array_CRT01, array_CRT02, array_CRT05, array_CRT06, array_CRT07,
       array_CRT08, array_CRT09, array_CRT12, array_CRT15, array_CRT16]

ax.boxplot(data, whis=(0,100))

ax.set_ylim(0.4, 1.4)
ax.tick_params(labelsize=15)
ax.set_ylabel('Average Surface Distance [mm]', fontsize=20)
ax.set_xlabel('Case', fontsize=20)



array_CRT01 = df_CRT01_haus.to_numpy()
array_CRT01 = array_CRT01.flatten()

array_CRT02 = df_CRT02_haus.to_numpy()
array_CRT02 = array_CRT02.flatten()

array_CRT05 = df_CRT05_haus.to_numpy()
array_CRT05 = array_CRT05.flatten()

array_CRT06 = df_CRT06_haus.to_numpy()
array_CRT06 = array_CRT06.flatten()

array_CRT07 = df_CRT07_haus.to_numpy()
array_CRT07 = array_CRT07.flatten()

array_CRT08 = df_CRT08_haus.to_numpy()
array_CRT08 = array_CRT08.flatten()

array_CRT09 = df_CRT09_haus.to_numpy()
array_CRT09 = array_CRT09.flatten()

array_CRT12 = df_CRT12_haus.to_numpy()
array_CRT12 = array_CRT12.flatten()

array_CRT15 = df_CRT15_haus.to_numpy()
array_CRT15 = array_CRT15.flatten()

array_CRT16 = df_CRT16_haus.to_numpy()
array_CRT16 = array_CRT16.flatten()

data2 = [array_CRT01, array_CRT02, array_CRT05, array_CRT06, array_CRT07,
       array_CRT08, array_CRT09, array_CRT12, array_CRT15, array_CRT16]

ax2.boxplot(data2, whis=(0,100))

ax2.set_ylim(2, 12)
ax2.tick_params(labelsize=15)
ax2.set_ylabel('Directed Hausdorff Distance [mm]', fontsize=20)
ax2.set_xlabel('Case', fontsize=20)

ax.scatter(cases, asd)
ax2.scatter(cases, dhd, label='Population Optimisation')

ax.scatter(cases, asd_LV)
ax2.scatter(cases, dhd_LV, label='LV Optimisation')

ax2.legend(fontsize=17)

#plt.savefig('Histograms-horz-1.png', dpi=150, bbox='tight')
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:103: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later

# %%
# This function will return a list of 
# positions where element exists 
# in the dataframe. 
def getIndexes(dfObj, value): 
      
    # Empty list 
    listOfPos = [] 
      
    # isin() method will return a dataframe with  
    # boolean values, True at the positions     
    # where element exists 
    result = dfObj.isin([value]) 
      
    # any() method will return  
    # a boolean series 
    seriesObj = result.any() 
  
    # Get list of column names where  
    # element exists 
    columnNames = list(seriesObj[seriesObj == True].index) 
     
    # Iterate over the list of columns and 
    # extract the row index where element exists 
    for col in columnNames: 
        rows = list(result[col][result[col] == True].index) 
  
        for row in rows: 
            listOfPos.append((row, col)) 
              
    # This list contains a list tuples with  
    # the index of element in the dataframe 
    return listOfPos

# %%
BE_list = []
SW_list = []

BE_SW_list = []

for df in [df_CRT01, df_CRT02, df_CRT05, df_CRT06, df_CRT07, df_CRT08, df_CRT09, df_CRT12, df_CRT15, df_CRT16]:   
    
    BE_SW = getIndexes(df, df.min().min())
    BE_SW_list.append(BE_SW)
    
    BE_list.append(BE_SW[0][0])
    SW_list.append(BE_SW[0][1])

# %%
BE_SW_list
# Out:
# [[('4e-7', '3e-4')],
#  [('4e-8', '9e-2')],
#  [('4e-6', '3e-4')],
#  [('4e-9', '0.00')],
#  [('4e-7', '0.00')],
#  [('4e-10', '9e-4')],
#  [('1e-6', '9e-2')],
#  [('1e-7', '3e-4')],
#  [('1e-8', '0.00')],
#  [('4e-9', '3e-4')]]

# %%
set(SW_list)
# Out:
# {'0.00', '3e-4', '9e-2', '9e-4'}

# %%
set(BE_list)
# Out:
# {'1e-6', '1e-7', '1e-8', '4e-10', '4e-6', '4e-7', '4e-8', '4e-9'}

# %%
BE_list_labels = []

for i in range(0,10):
    BE_list_labels.append([BE_list[i],i+1])

# %%
BE_list_labels

# %%
for BE_label in BE_list_labels:
    float(BE_label[0])

# %%
type(BE_list_labels[0][0])

# %%
[float(i) for i in BE_list_labels]

# %%
BE_list = [float(i) for i in BE_list]
SW_list = [float(i) for i in SW_list]

SW_list.sort()
BE_list.sort()

BE_list = [str(i) for i in BE_list]
SW_list = [str(i) for i in SW_list]

# %%
BE_list_haus = []
SW_list_haus = []

BE_SW_haus_list = []

for df in [df_CRT01_haus, df_CRT02_haus, df_CRT05_haus, df_CRT06_haus, df_CRT07_haus,
           df_CRT08_haus, df_CRT09_haus, df_CRT12_haus, df_CRT15_haus, df_CRT16_haus]:   
    
    BE_SW_haus = getIndexes(df, df.min().min())
    BE_SW_haus_list.append(BE_SW_haus)
    
    BE_list_haus.append(BE_SW_haus[0][0])
    SW_list_haus.append(BE_SW_haus[0][1])

# %%
BE_SW_haus_list
# Out:
# [[('4e-7', '3e-4')],
#  [('4e-7', '9e-2')],
#  [('4e-9', '3e-4')],
#  [('4e-10', '9e-2')],
#  [('1e-7', '9e-4')],
#  [('4e-10', '9e-4')],
#  [('4e-6', '9e-2')],
#  [('4e-6', '3e-4')],
#  [('4e-6', '9e-2')],
#  [('4e-8', '9e-2')]]

# %%
## Turns BE_list_haus adn SW_list_haus into floats, sorrts them into ascending order, then outputs as strings

BE_list_haus = [float(i) for i in BE_list_haus]
SW_list_haus = [float(i) for i in SW_list_haus]

SW_list_haus.sort()
BE_list_haus.sort()

BE_list_haus = [str(i) for i in BE_list_haus]
SW_list_haus = [str(i) for i in SW_list_haus]

# %%
(BE_SW_list)
# Out:
# [[('4e-7', '3e-4')],
#  [('4e-8', '9e-2')],
#  [('4e-6', '3e-4')],
#  [('4e-9', '0.00')],
#  [('4e-7', '0.00')],
#  [('4e-10', '9e-4')],
#  [('1e-6', '9e-2')],
#  [('1e-7', '3e-4')],
#  [('1e-8', '0.00')],
#  [('4e-9', '3e-4')]]

# %%
BE_SW_haus_list
# Out:
# [[('4e-7', '3e-4')],
#  [('4e-7', '9e-2')],
#  [('4e-9', '3e-4')],
#  [('4e-10', '9e-2')],
#  [('1e-7', '9e-4')],
#  [('4e-10', '9e-4')],
#  [('4e-6', '9e-2')],
#  [('4e-6', '3e-4')],
#  [('4e-6', '9e-2')],
#  [('4e-8', '9e-2')]]

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.gca()

#plt.yticks(np.arange(4), labels=['0.0', '3e-4', '9e-4', '9e-2'])

#ax.scatter(BE_list, SW_list, s=500)  
#ax.scatter(BE_list_haus, SW_list_haus, marker='x', c='r', s=500)

ax.scatter(float(BE_SW_list[0][0][0]), float(BE_SW_list[0][0][1]), label='Case 1')
ax.scatter(float(BE_SW_list[1][0][0]), float(BE_SW_list[1][0][1]), label='Case 2')
ax.scatter(float(BE_SW_list[2][0][0]), float(BE_SW_list[2][0][1]), label='Case 3')
ax.scatter(float(BE_SW_list[3][0][0]), float(BE_SW_list[3][0][1]), label='Case 4')
ax.scatter(float(BE_SW_list[4][0][0]), float(BE_SW_list[4][0][1]), label='Case 5')
ax.scatter(float(BE_SW_list[5][0][0]), float(BE_SW_list[5][0][1]), label='Case 6')
ax.scatter(float(BE_SW_list[6][0][0]), float(BE_SW_list[6][0][1]), label='Case 7')
ax.scatter(float(BE_SW_list[7][0][0]), float(BE_SW_list[7][0][1]), label='Case 8')
ax.scatter(float(BE_SW_list[8][0][0]), float(BE_SW_list[8][0][1]), label='Case 9')
ax.scatter(float(BE_SW_list[9][0][0]), float(BE_SW_list[9][0][1]), label='Case 10')


ax.set_xscale('log')
#ax.set_xlim(1e-10, 1e-5)

ax.set_yscale('symlog')
#plt.yticks([0.0, 1e-4, 1e-3, 1e-2, 1e-1])
#ax.set_ylim(-1e-3, 1e-1)
ax.tick_params(labelsize=15)

ax.set_ylabel('Sparsity Weight', fontsize=20)
ax.set_xlabel('Bending Energy', fontsize=20)

ax.legend(fontsize=15)

# %%
BE_SW_haus_list
# Out:
# [[('4e-7', '3e-4')],
#  [('4e-7', '9e-2')],
#  [('4e-9', '3e-4')],
#  [('4e-10', '9e-2')],
#  [('1e-7', '9e-4')],
#  [('4e-10', '9e-4')],
#  [('4e-6', '9e-2')],
#  [('4e-6', '3e-4')],
#  [('4e-6', '9e-2')],
#  [('4e-8', '9e-2')]]

# %%
fig, (ax, ax2) = plt.subplots(2, 1, sharex=True, figsize=(18,15))

#plt.yticks(np.arange(4), labels=['0.0', '3e-4', '9e-4', '9e-2'])

#ax.scatter(BE_list, SW_list, s=800)  
#ax.scatter(BE_list_haus, SW_list_haus, marker='x', c='r', s=800)

# ax is for the 'outliers' i.e. ASD: Case 2 and Case 7

ax.scatter(float(BE_SW_list[0][0][0]), float(BE_SW_list[0][0][1]), s=800, label='Case 1', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[1][0][0]), float(BE_SW_list[1][0][1]), s=800, edgecolors='b', marker=7)
ax.scatter(float(BE_SW_list[2][0][0]), float(BE_SW_list[2][0][1]), s=800, label='Case 3', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[3][0][0]), float(BE_SW_list[3][0][1]), s=800, label='Case 4', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[4][0][0]), float(BE_SW_list[4][0][1]), s=800, label='Case 5', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[5][0][0]), float(BE_SW_list[5][0][1]), s=800, label='Case 6', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[6][0][0]), float(BE_SW_list[6][0][1]), s=800, edgecolors='b', marker=7)
ax.scatter(float(BE_SW_list[7][0][0]), float(BE_SW_list[7][0][1]), s=800, label='Case 8', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[8][0][0]), float(BE_SW_list[8][0][1]), s=800, label='Case 9', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[9][0][0]), float(BE_SW_list[9][0][1]), s=800, label='Case 10', edgecolors='b', marker='s')

ax.scatter(float(BE_SW_haus_list[0][0][0]), float(BE_SW_haus_list[0][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[1][0][0]), float(BE_SW_haus_list[1][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[2][0][0]), float(BE_SW_haus_list[2][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[3][0][0]), float(BE_SW_haus_list[3][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[4][0][0]), float(BE_SW_haus_list[4][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[5][0][0]), float(BE_SW_haus_list[5][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[6][0][0]), float(BE_SW_haus_list[6][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[7][0][0]), float(BE_SW_haus_list[7][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[8][0][0]), float(BE_SW_haus_list[8][0][1]), s=250, marker=6, edgecolors='b')
ax.scatter(float(BE_SW_haus_list[9][0][0]), float(BE_SW_haus_list[9][0][1]), s=250, marker=6, edgecolors='b')

ax.scatter(1e-6, 3e-3, s=800, c='black', marker='s', label='Population')

ax2.scatter(float(BE_SW_list[0][0][0]), float(BE_SW_list[0][0][1]), s=800, edgecolors='b', marker=7)
ax2.scatter(float(BE_SW_list[1][0][0]), float(BE_SW_list[1][0][1]), s=800, label='Case 2', edgecolors='b', marker='s')
ax2.scatter(float(BE_SW_list[2][0][0]), float(BE_SW_list[2][0][1]), s=800, edgecolors='b', marker=7)
ax2.scatter(float(BE_SW_list[3][0][0]), float(BE_SW_list[3][0][1]), s=800, edgecolors='b', marker=7)
ax2.scatter(float(BE_SW_list[4][0][0]), float(BE_SW_list[4][0][1]), s=800, edgecolors='b', marker=7)
ax2.scatter(float(BE_SW_list[5][0][0]), float(BE_SW_list[5][0][1]), s=800, edgecolors='b', marker=7)
ax2.scatter(float(BE_SW_list[6][0][0]), float(BE_SW_list[6][0][1]), s=800, label='Case 7', edgecolors='b', marker='s')
ax2.scatter(float(BE_SW_list[7][0][0]), float(BE_SW_list[7][0][1]), s=800, edgecolors='b', marker=7)
ax2.scatter(float(BE_SW_list[8][0][0]), float(BE_SW_list[8][0][1]), s=800, edgecolors='b', marker=7)
ax2.scatter(float(BE_SW_list[9][0][0]), float(BE_SW_list[9][0][1]), s=800, edgecolors='b', marker=7)

ax2.scatter(float(BE_SW_haus_list[0][0][0]), float(BE_SW_haus_list[0][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[1][0][0]), float(BE_SW_haus_list[1][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[2][0][0]), float(BE_SW_haus_list[2][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[3][0][0]), float(BE_SW_haus_list[3][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[4][0][0]), float(BE_SW_haus_list[4][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[5][0][0]), float(BE_SW_haus_list[5][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[6][0][0]), float(BE_SW_haus_list[6][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[7][0][0]), float(BE_SW_haus_list[7][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[8][0][0]), float(BE_SW_haus_list[8][0][1]), s=250, marker=6, edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[9][0][0]), float(BE_SW_haus_list[9][0][1]), s=250, marker=6, edgecolors='b')

ax2.scatter(1e-6, 3e-3, s=800, c='black', marker=7)
ax2.scatter(1e-6, 3e-4, s=250, c='black', marker=6)

# zoom-in / limit the view to different portions of the data
ax.set_ylim(8.99e-2, 9.01e-2)  # outliers only
ax2.set_ylim(-1e-4, 3.2e-3)  # most of the data

# hide the spines between ax and ax2
ax.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.xaxis.tick_bottom()

d = .005  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

ax.set_xscale('log')
ax.set_xlim(1e-10, 1e-5)

ax.set_yscale('symlog')
#plt.yticks([0.0, 1e-4, 1e-3, 1e-2, 1e-1])
#ax.set_ylim(-1e-3, 1e-1)
ax.tick_params(labelsize=20)
ax2.tick_params(labelsize=20)

ax2.set_xlabel('Bending Energy', fontsize=30)

ax.set_yticks(ticks=[9e-2])
ax2.set_yticks(ticks=[0.0, 3e-4, 9e-4, 3e-3])

fig.text(0.04, 0.5, 'Sparsity Weight', ha='center', va='center', rotation='vertical', fontsize=30)


ax.set_xticks(ticks=[1e-10, 4e-10, 1e-9, 4e-9, 1e-8, 4e-8, 1e-7, 4e-7, 1e-6, 4e-6, 1e-5])

ax.legend(fontsize=25, bbox_to_anchor=(1, 1), loc='upper left')
ax2.legend(fontsize=25, bbox_to_anchor=(1, 1), loc='upper left')

plt.savefig('ParameterSpace-2.png', dpi=150, bbox_inches='tight')

# %%
fig, (ax, ax2) = plt.subplots(2, 1, sharex=True, figsize=(18,15))

#plt.yticks(np.arange(4), labels=['0.0', '3e-4', '9e-4', '9e-2'])

#ax.scatter(BE_list, SW_list, s=600)  
#ax.scatter(BE_list_haus, SW_list_haus, marker='D', c='r', s=600)

# ax is for the 'outliers' i.e. ASD: Case 2 and Case 7. Labels only for points which are not seen on ax.

ax.scatter(float(BE_SW_list[0][0][0]), float(BE_SW_list[0][0][1]), s=600, label='Case 1', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[1][0][0]), float(BE_SW_list[1][0][1]), s=600, edgecolors='b', facecolor='none', linewidth=5)
ax.scatter(float(BE_SW_list[2][0][0]), float(BE_SW_list[2][0][1]), s=600, label='Case 3', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[3][0][0]), float(BE_SW_list[3][0][1]), s=600, label='Case 4', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[4][0][0]), float(BE_SW_list[4][0][1]), s=600, label='Case 5', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[5][0][0]), float(BE_SW_list[5][0][1]), s=600, label='Case 6', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[6][0][0]), float(BE_SW_list[6][0][1]), s=600, edgecolors='b', facecolor='none', linewidth=5)
ax.scatter(float(BE_SW_list[7][0][0]), float(BE_SW_list[7][0][1]), s=600, label='Case 8', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[8][0][0]), float(BE_SW_list[8][0][1]), s=600, label='Case 9', edgecolors='b', marker='s')
ax.scatter(float(BE_SW_list[9][0][0]), float(BE_SW_list[9][0][1]), s=600, label='Case 10', edgecolors='b', marker='s')

ax.scatter(float(BE_SW_haus_list[0][0][0]), float(BE_SW_haus_list[0][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[1][0][0]), float(BE_SW_haus_list[1][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[2][0][0]), float(BE_SW_haus_list[2][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[3][0][0]), float(BE_SW_haus_list[3][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[4][0][0]), float(BE_SW_haus_list[4][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[5][0][0]), float(BE_SW_haus_list[5][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[6][0][0]), float(BE_SW_haus_list[6][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[7][0][0]), float(BE_SW_haus_list[7][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[8][0][0]), float(BE_SW_haus_list[8][0][1]), s=200, marker='D', edgecolors='b')
ax.scatter(float(BE_SW_haus_list[9][0][0]), float(BE_SW_haus_list[9][0][1]), s=200, marker='D', edgecolors='b')

ax.scatter(1e-6, 3e-3, s=600, c='black', marker='s', label='Population')

ax2.scatter(float(BE_SW_list[0][0][0]), float(BE_SW_list[0][0][1]), s=600, edgecolors='#1f77b4', facecolor='none', linewidth=5)
ax2.scatter(float(BE_SW_list[1][0][0]), float(BE_SW_list[1][0][1]), s=600, label='Case 2', edgecolors='b', marker='s')
ax2.scatter(float(BE_SW_list[2][0][0]), float(BE_SW_list[2][0][1]), s=600, edgecolors='b', facecolor='none',  linewidth=5)
ax2.scatter(float(BE_SW_list[3][0][0]), float(BE_SW_list[3][0][1]), s=600, edgecolors='b', facecolor='none',  linewidth=5)
ax2.scatter(float(BE_SW_list[4][0][0]), float(BE_SW_list[4][0][1]), s=600, edgecolors='b', facecolor='none',  linewidth=5)
ax2.scatter(float(BE_SW_list[5][0][0]), float(BE_SW_list[5][0][1]), s=600, edgecolors='b', facecolor='none',  linewidth=5)
ax2.scatter(float(BE_SW_list[6][0][0]), float(BE_SW_list[6][0][1]), s=600, label='Case 7', edgecolors='b', marker='s')
ax2.scatter(float(BE_SW_list[7][0][0]), float(BE_SW_list[7][0][1]), s=600, edgecolors='b', facecolor='none',  linewidth=5)
ax2.scatter(float(BE_SW_list[8][0][0]), float(BE_SW_list[8][0][1]), s=600, edgecolors='b', facecolor='none',  linewidth=5)
ax2.scatter(float(BE_SW_list[9][0][0]), float(BE_SW_list[9][0][1]), s=600, edgecolors='b', facecolor='none', linewidth=5)

ax2.scatter(float(BE_SW_haus_list[0][0][0]), float(BE_SW_haus_list[0][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[1][0][0]), float(BE_SW_haus_list[1][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[2][0][0]), float(BE_SW_haus_list[2][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[3][0][0]), float(BE_SW_haus_list[3][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[4][0][0]), float(BE_SW_haus_list[4][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[5][0][0]), float(BE_SW_haus_list[5][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[6][0][0]), float(BE_SW_haus_list[6][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[7][0][0]), float(BE_SW_haus_list[7][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[8][0][0]), float(BE_SW_haus_list[8][0][1]), s=200, marker='D', edgecolors='b')
ax2.scatter(float(BE_SW_haus_list[9][0][0]), float(BE_SW_haus_list[9][0][1]), s=200, marker='D', edgecolors='b')

ax2.scatter(1e-6, 3e-3, s=600, c='black', facecolor='none', linewidth=5)
ax2.scatter(1e-6, 3e-4, s=200, c='black', marker='D')

# zoom-in / limit the view to different portions of the data
ax.set_ylim(8.9e-2, 9.05e-2)  # outliers only
ax2.set_ylim(-1e-4, 3.2e-3)  # most of the data

# hide the spines between ax and ax2
ax.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.xaxis.tick_bottom()

d = .005  # how big to make the diagonal lines in axes coordinates
# arguments to pass to plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

ax.set_xscale('log')
ax.set_xlim(1e-10, 1e-5)

ax.set_yscale('symlog')
#plt.yticks([0.0, 1e-4, 1e-3, 1e-2, 1e-1])
#ax.set_ylim(-1e-3, 1e-1)
ax.tick_params(labelsize=15)
ax2.tick_params(labelsize=15)

ax2.set_xlabel('Bending Energy', fontsize=20)

ax.set_yticks(ticks=[9e-2])
ax2.set_yticks(ticks=[0.0, 3e-4, 9e-4, 3e-3])

fig.text(0.06, 0.5, 'Sparsity Weight', ha='center', va='center', rotation='vertical', fontsize=20)


ax.set_xticks(ticks=[1e-10, 4e-10, 1e-9, 4e-9, 1e-8, 4e-8, 1e-7, 4e-7, 1e-6, 4e-6, 1e-5])
ax2.set_xticks(ticks=[1e-10, 4e-10, 1e-9, 4e-9, 1e-8, 4e-8, 1e-7, 4e-7, 1e-6, 4e-6, 1e-5])

ax.legend(fontsize=15, bbox_to_anchor=(1, 1), loc='upper left')
ax2.legend(fontsize=15, bbox_to_anchor=(1, 1), loc='upper left')

#plt.savefig('ParameterSpace.png', dpi=150)

# %%
for df in [df_CRT01, df_CRT02, df_CRT05, df_CRT06, df_CRT07,
           df_CRT08, df_CRT09, df_CRT12, df_CRT15, df_CRT16]:
    
    print(df.min().min())
# Out:
# 0.7295733516824883
# 0.587505838
# 0.8333377778
# 0.9554333495
# 0.954265233
# 0.7473558331
# 0.5463238921
# 0.6547913213000001
# 0.8861253089
# 0.6092392978

# %%
for df in [df_CRT01_haus, df_CRT02_haus, df_CRT05_haus, df_CRT06_haus, df_CRT07_haus,
           df_CRT08_haus, df_CRT09_haus, df_CRT12_haus, df_CRT15_haus, df_CRT16_haus]:
    
    print(df.min().min())
# Out:
# 3.9576003280000003
# 3.285265988
# 5.826671922
# 6.56243581
# 4.990858572
# 3.218127575
# 6.71654818
# 4.4563831369999996
# 5.698746551
# 6.250135698999999

# %%
list = [df_CRT01, df_CRT02, df_CRT05, df_CRT06, df_CRT07, df_CRT08, df_CRT09, df_CRT12, df_CRT15, df_CRT16]

df_pop = sum(list)

# %%
df_pop
# Out:
#            9e-2      3e-2      9e-3      3e-3      9e-4      3e-4      0.00
# 4e-6   7.821048  8.195319  8.192963  7.884853  8.040293  7.863963  8.384217
# 1e-6   8.240857  8.169048  8.281003  7.809383  7.866979  7.880983  8.006994
# 4e-7   8.025648  8.002816  8.264047  8.173958  8.157391  8.310317  7.927815
# 1e-7   8.270549  8.145829  8.051895  7.947047  7.869207  7.919364  8.316656
# 4e-8   8.023427  8.044175  8.139277  8.080740  8.280840  8.162383  8.239391
# 1e-8   8.026747  8.185659  8.170169  8.032155  8.045286  8.007189  7.895063
# 4e-9   8.083883  8.163076  8.142921  8.236514  8.038296  7.845644  7.945138
# 1e-9   8.184735  7.927013  7.996531  8.193044  7.840772  7.812162  8.071561
# 4e-10  8.319807  8.007290  8.028936  8.199949  7.990296  7.834693  8.062906

# %%
getIndexes(df_pop, 7.809382770896896)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-6e3eb30fb4a8> in <module>
# ----> 1 getIndexes(df_pop, 7.809382770896896)
#
# <ipython-input-8-672cdc02f5cd> in getIndexes(dfObj, value)
#      18     # Get list of column names where
#      19     # element exists
# ---> 20     columnNames = list(seriesObj[seriesObj == True].index)
#      21
#      22     # Iterate over the list of columns and
#
# TypeError: 'list' object is not callable

# %%
df_pop.min()
# Out:
# 9e-2    7.821048
# 3e-2    7.927013
# 9e-3    7.996531
# 3e-3    7.809383
# 9e-4    7.840772
# 3e-4    7.812162
# 0.00    7.895063
# dtype: float64

# %%
BE_list_pop = []
SW_list_pop = []

BE_SW_list_pop = []

df = df_pop   
    
a = getIndexes(df, df.min().min())
BE_SW_list_pop.append(a)
    
BE_list_pop.append(a[0][0])
SW_list_pop.append(a[0][1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-1af1d65caa45> in <module>
#       6 df = df_pop
#       7
# ----> 8 a = getIndexes(df, df.min().min())
#       9 BE_SW_list_pop.append(a)
#      10
#
# <ipython-input-8-672cdc02f5cd> in getIndexes(dfObj, value)
#      18     # Get list of column names where
#      19     # element exists
# ---> 20     columnNames = list(seriesObj[seriesObj == True].index)
#      21
#      22     # Iterate over the list of columns and
#
# TypeError: 'list' object is not callable

# %%
list_haus = [df_CRT01_haus, df_CRT02_haus, df_CRT05_haus, df_CRT06_haus, df_CRT07_haus,
        df_CRT08_haus, df_CRT09_haus, df_CRT12_haus, df_CRT15_haus, df_CRT16_haus]

df_pop_haus = sum(list_haus)

# %%
df_pop_haus
# Out:
#             9e-2       3e-2       9e-3       3e-3       9e-4       3e-4  \
# 4e-6   57.320743  60.704813  59.244363  57.537285  56.681830  58.598299
# 1e-6   58.270443  60.924964  63.639547  57.406540  58.392770  56.252246
# 4e-7   60.087268  60.662396  58.818716  61.919737  62.800698  60.409655
# 1e-7   60.006455  60.669035  58.602181  58.039212  58.665540  57.470371
# 4e-8   57.833361  59.226638  61.326985  57.056511  59.748993  59.821951
# 1e-8   60.081809  60.394106  61.697301  57.993400  57.802785  58.421673
# 4e-9   58.672417  62.565262  61.896990  59.671624  56.838067  56.265743
# 1e-9   59.868256  62.385203  56.576586  57.188838  57.544185  57.716839
# 4e-10  58.101250  60.883895  56.771316  58.735164  57.953025  56.722882
#
#             0.00
# 4e-6   59.742364
# 1e-6   61.590927
# 4e-7   61.203388
# 1e-7   62.249044
# 4e-8   61.241137
# 1e-8   60.769583
# 4e-9   62.340331
# 1e-9   61.669066
# 4e-10  60.441545

# %%
df_pop_haus.min()
# Out:
# 9e-2    57.320743
# 3e-2    59.226638
# 9e-3    56.576586
# 3e-3    57.056511
# 9e-4    56.681830
# 3e-4    56.252246
# 0.00    59.742364
# dtype: float64

# %%
df_pop_haus.min().min()
# Out:
# 56.252245792000004
