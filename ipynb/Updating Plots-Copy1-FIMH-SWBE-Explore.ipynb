# %% [markdown]
# Updting for desktop usage with Seagate

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
basePath="/media/cs1623/Seagate Portable Drive/Master/Data/RG_CT_Cases"

# %%
Res = 'MT'
csv_name = 'Normal-Distance-Results'

ASD_baseline = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    ASD_baseline.append(test_reread.loc[4e-7]['9e-3'])

Res = 'MT-HiRes'
csv_name = 'Normal-Distance-Results'

ASD_Optimised = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    ASD_Optimised.append(test_reread.loc[1e-6]['9e-3'])

Res = 'MT'

csv_name = 'Hausdorff-Distance-Results'

DHD_baseline = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    DHD_baseline.append(test_reread.loc[4e-7]['9e-3'])

Res = 'MT-HiRes'

csv_name = 'Hausdorff-Distance-Results'

DHD_Optimised = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    DHD_Optimised.append(test_reread.loc[1e-6]['9e-3'])

Res = 'MT'

csv_name = 'Dice-Results'

DSC_baseline = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    DHD_baseline.append(test_reread.loc[4e-7]['9e-3'])

# %%
Res = 'MT'

csv_name = 'PVeinsCropped-Dice-Results'

Dice_baseline = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    Dice_baseline.append(test_reread.loc[4e-7]['9e-3'])

# %%
Res = 'MT-HiRes'

csv_name = 'PVeinsCropped-Dice-Results'

Dice_Optimised = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    Dice_Optimised.append(test_reread.loc[1e-7]['9e-3'])

# %%
ASD_total = [ASD_baseline, ASD_Optimised]
DHD_total = [DHD_baseline, DHD_Optimised]
Dice_total = [Dice_baseline, Dice_Optimised]

# %%
DHD_Optimised

# %%
fig, ((ax, ax2, ax3)) = plt.subplots(1, 3, figsize=(10,3), dpi=150)

ax.boxplot(ASD_total, medianprops=dict(c='black'))
ax2.boxplot(DHD_total, medianprops=dict(c='black'))
ax3.boxplot(Dice_total, medianprops=dict(c='black'))

ax.set_title('ASD [mm]', fontsize=20)
ax2.set_title('DHD [mm]', fontsize=20)
ax3.set_title('DSC', fontsize=20)

ax.set_xticks([1, 2])
ax2.set_xticks([1, 2])
ax3.set_xticks([1, 2])

ax.set_xticklabels(['Baseline', 'Optimised'], fontsize=12)
ax2.set_xticklabels(['Baseline', 'Optimised'], fontsize=12)
ax3.set_xticklabels(['Baseline', 'Optimised'], fontsize=12)

# plt.savefig('FIMH_poster_histograms', dpi=150, bbox_inches='tight')

# %%
Res = 'MT'

csv_name = 'Normal-Distance-Results'

ASD_data_MT = []
ASD_pop_MT = []
ASD_LV_MT = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    ASD_pop = test_reread.loc[1e-6]['3e-3']
    ASD_LV = test_reread.loc[4e-7]['9e-3']
    
    test_reread = test_reread.to_numpy()
    test_reread = test_reread.flatten()
    
    ASD_data_MT.append(test_reread)
    ASD_pop_MT.append(ASD_pop)
    ASD_LV_MT.append(ASD_LV)

# %%
Res = 'MT'

csv_name = 'Hausdorff-Distance-Results'

DHD_data_MT = []
DHD_pop_MT = []
DHD_LV_MT = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    DHD_pop = test_reread.loc[1e-6]['3e-4']
    DHD_LV = test_reread.loc[4e-7]['9e-3']
    
    test_reread = test_reread.to_numpy()
    test_reread = test_reread.flatten()
    
    DHD_data_MT.append(test_reread)
    DHD_pop_MT.append(DHD_pop)
    DHD_LV_MT.append(DHD_LV)

# %%
Res = 'MT'

csv_name = 'PVeinsCropped-Dice-Results'
# csv_name = 'Dice-Results'

Dice_data_MT = []
Dice_pop_MT = []
Dice_LV_MT = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-{i}/csv_results/{Res}-{csv_name}.csv', 
           sep = ' ', index_col = 0)
    
    Dice_pop = test_reread.loc[1e-6]['3e-3']
    Dice_LV = test_reread.loc[4e-7]['9e-3']
    
    test_reread = test_reread.to_numpy()
    test_reread = test_reread.flatten()
    
    Dice_data_MT.append(test_reread)
    Dice_pop_MT.append(Dice_pop)
    Dice_LV_MT.append(Dice_LV)

# %%
Res = 'MT-HiRes'

csv_name = 'Normal-Distance-Results'

ASD_data_MT_HR = []
ASD_pop_MT_HR = []
ASD_LV_MT_HR = []

ASD_data_MT_HR = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-' + i + '/csv_results/' + Res + '-' + csv_name + '.csv', 
           sep = ' ', index_col = 0)
    
    ASD_pop = test_reread.loc[1e-6]['9e-3']
    ASD_LV = test_reread.loc[4e-7]['9e-3']
    
    test_reread = test_reread.to_numpy()
    test_reread = test_reread.flatten()
    
    ASD_data_MT_HR.append(test_reread)
    ASD_pop_MT_HR.append(ASD_pop)
    ASD_LV_MT_HR.append(ASD_LV)

# %%
Res = 'MT-HiRes'

csv_name = 'Hausdorff-Distance-Results'

DHD_data_MT_HR = []
DHD_pop_MT_HR = []
DHD_LV_MT_HR = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-' + i + '/csv_results/' + Res + '-' + csv_name + '.csv', 
           sep = ' ', index_col = 0)
    
    DHD_pop = test_reread.loc[4e-9]['9e-3']
    DHD_LV = test_reread.loc[4e-7]['9e-3']
    
    test_reread = test_reread.to_numpy()
    test_reread = test_reread.flatten()
    
    DHD_data_MT_HR.append(test_reread)
    DHD_pop_MT_HR.append(DHD_pop)
    DHD_LV_MT_HR.append(DHD_LV)

# %%
Res = 'MT-HiRes'

# csv_name = 'PVeinsCropped-Dice-Results'
csv_name = 'Dice-Results'

Dice_data_MT_HR = []
Dice_pop_MT_HR = []
Dice_LV_MT_HR = []

for i in ['01', '02', '05', '06', '07', '08', '09', '12', '15', '16']:
    
    test_reread = pd.read_csv(f'{basePath}/CT-CRT-' + i + '/csv_results/' + Res + '-' + csv_name + '.csv', 
           sep = ' ', index_col = 0)
    
    Dice_pop = test_reread.loc[1e-6]['3e-3']
    Dice_LV = test_reread.loc[4e-7]['9e-3']
    
    test_reread = test_reread.to_numpy()
    test_reread = test_reread.flatten()
    
    Dice_data_MT_HR.append(test_reread)
    Dice_pop_MT_HR.append(Dice_pop)
    Dice_LV_MT_HR.append(Dice_LV)

# %%
len(DHD_data_MT[0])

# %%
len(ASD_data_MT[0])

# %%
fig, ((ax, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(18,27), dpi=150, sharey='row')

ax.boxplot(ASD_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax2.boxplot(ASD_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))
ax3.boxplot(DHD_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax4.boxplot(DHD_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))
ax5.boxplot(Dice_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax6.boxplot(Dice_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))

cases = list(np.arange(1,11,1))

ax.scatter(cases, ASD_pop_MT, label = 'Population Optimisation')
ax.scatter(cases, ASD_LV_MT, label = 'LV Optimisation')

ax2.scatter(cases, ASD_pop_MT_HR, label = 'Population Optimisation')
ax2.scatter(cases, ASD_LV_MT_HR, label = 'LV Optimisation')
ax2.legend(fontsize=17)

ax3.scatter(cases, DHD_pop_MT, label = 'Population Optimisation')
ax3.scatter(cases, DHD_LV_MT, label = 'LV Optimisation')

ax4.scatter(cases, DHD_pop_MT_HR, label = 'Population Optimisation')
ax4.scatter(cases, DHD_LV_MT_HR, label = 'LV Optimisation')
ax4.legend(fontsize=17)

ax5.scatter(cases, Dice_pop_MT, label = 'Population Optimisation')
ax5.scatter(cases, Dice_LV_MT, label = 'LV Optimisation')

ax6.scatter(cases, Dice_pop_MT_HR, label = 'Population Optimisation')
ax6.scatter(cases, Dice_LV_MT_HR, label = 'LV Optimisation')

ax.set_ylabel('Average Surface Distance [mm]', fontsize=20)
ax.tick_params(labelsize=15)
ax.set_title('LV-Res', fontsize=20, pad=15)
ax.set_ylim(0.2, 1.4)

ax2.tick_params(labelsize=15)
ax2.set_title('Hi-Res', fontsize=20, pad=15)

ax3.set_ylabel('Directed Hausdorff Distance [mm]', fontsize=20)
ax3.tick_params(labelsize=15)
ax3.set_ylim(1, 12)

ax4.tick_params(labelsize=15)

ax5.set_ylabel('Dice Score (LA Body)', fontsize=20)
ax5.set_xlabel('Case', fontsize=20)
ax5.tick_params(labelsize=15)
ax5.set_ylim(0.84, 1.0)

ax6.set_xlabel('Case', fontsize=20)
ax6.tick_params(labelsize=15)
ax6.legend(fontsize=17)

for axis in [ax2, ax4, ax6]:
    axis.yaxis.set_tick_params(labelbottom=True)
    
# plt.savefig('Fig2-updating-2.png', dpi=150, bbox_inches='tight')

# %%
Dice_data_MT = [i*100 for i in Dice_data_MT]
Dice_data_MT_HR = [i*100 for i in Dice_data_MT_HR]

Dice_pop_MT = [i*100 for i in Dice_pop_MT]
Dice_pop_MT_HR = [i*100 for i in Dice_pop_MT_HR]
Dice_LV_MT = [i*100 for i in Dice_LV_MT]
Dice_LV_MT_HR = [i*100 for i in Dice_LV_MT_HR]

# %%
fig, ((ax, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(12,14), dpi=150, facecolor="white", sharey='row')

ax.boxplot(ASD_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax2.boxplot(ASD_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))
ax3.boxplot(DHD_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax4.boxplot(DHD_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))
ax5.boxplot(Dice_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax6.boxplot(Dice_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))

cases = list(np.arange(1,11,1))

ax.scatter(cases, ASD_pop_MT, label = 'LA (SW, BE) Optimisation')
ax.scatter(cases, ASD_LV_MT, label = 'LV (SW, BE) Optimisation')

ax2.scatter(cases, ASD_pop_MT_HR, label = 'LA (SW, BE) Optimisation')
ax2.scatter(cases, ASD_LV_MT_HR, label = 'LV (SW, BE) Optimisation')

ax3.scatter(cases, DHD_pop_MT, label = 'LA (SW, BE) Optimisation')
ax3.scatter(cases, DHD_LV_MT, label = 'LV (SW, BE) Optimisation')

ax4.scatter(cases, DHD_pop_MT_HR, label = 'LA (SW, BE) Optimisation')
ax4.scatter(cases, DHD_LV_MT_HR, label = 'LV (SW, BE) Optimisation')

ax5.scatter(cases, Dice_pop_MT, label = 'LA (SW, BE) Optimisation')
ax5.scatter(cases, Dice_LV_MT, label = 'LV (SW, BE) Optimisation')

ax6.scatter(cases, Dice_pop_MT_HR, label = 'LA (SW, BE) Optimisation')
ax6.scatter(cases, Dice_LV_MT_HR, label = 'LV (SW, BE) Optimisation')

ax.set_ylabel('ASD [mm]', fontsize=20)
ax.tick_params(labelsize=15)
ax.set_title('LV-Res', fontsize=20, pad=15)
ax.set_ylim(0.2, 1.4)

ax2.tick_params(labelsize=15)
ax2.set_title('Hi-Res', fontsize=20, pad=15)

ax3.set_ylabel('DHD [mm]', fontsize=20)
ax3.tick_params(labelsize=15)
ax3.set_ylim(1, 12)

ax4.tick_params(labelsize=15)

for ax in [ax2, ax4, ax6]:
    ax.legend(fontsize=15)

ax5.set_ylabel('DSC [%]', fontsize=20)
ax5.set_xlabel('Case', fontsize=20)
ax5.tick_params(labelsize=15)
ax5.set_ylim(86, 100)

ax6.set_xlabel('Case', fontsize=20)
ax6.tick_params(labelsize=15)

for axis in [ax2, ax4, ax6]:
    axis.yaxis.set_tick_params(labelbottom=True)

plt.tight_layout()
# plt.savefig('/home/csi20/Dropbox/phd/Documents/thesis/figs/4_framework/FIMH_explore_TSFFDopt.png', dpi=150, bbox_inches='tight')

# %%
## FOR UPGRADE REPORT

fig, ((ax, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2, figsize=(10,15), dpi=150, sharey='row')

ax.boxplot(ASD_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax2.boxplot(ASD_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))
ax3.boxplot(DHD_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax4.boxplot(DHD_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))
ax5.boxplot(Dice_data_MT, whis=(0,100), medianprops=dict(c='black'))
ax6.boxplot(Dice_data_MT_HR, whis=(0,100), medianprops=dict(c='black'))

cases = list(np.arange(1,11,1))

# ax.scatter(cases, ASD_pop_MT, label = 'Population Optimisation')
ax.scatter(cases, ASD_LV_MT, color='red', label = 'Baseline')
ax.legend(fontsize=15)

ax2.scatter(cases, ASD_pop_MT_HR, label = 'Optimised')
# ax2.scatter(cases, ASD_LV_MT_HR, label = 'LV Optimisation')
ax2.legend(fontsize=15)

# ax3.scatter(cases, DHD_pop_MT, label = 'Population Optimisation')
ax3.scatter(cases, DHD_LV_MT, color='red', label = 'Baseline')

ax4.scatter(cases, DHD_pop_MT_HR, label = 'Optimised')
# ax4.scatter(cases, DHD_LV_MT_HR, label = 'LV Optimisation')

# ax5.scatter(cases, Dice_pop_MT, label = 'Optimised')
ax5.scatter(cases, Dice_LV_MT, color='red', label = 'Baseline')

ax6.scatter(cases, Dice_pop_MT_HR, label = 'Optimised')
# ax6.scatter(cases, Dice_LV_MT_HR, label = 'LV Optimisation')

ax.set_ylabel('ASD [mm]', fontsize=15)
ax.tick_params(labelsize=12)
ax.set_title('LV-Res', fontsize=15, pad=15)
ax.set_ylim(0.2, 1.4)

ax2.tick_params(labelsize=12)
ax2.set_title('Hi-Res', fontsize=15, pad=15)

ax3.set_ylabel('DHD [mm]', fontsize=15)
ax3.tick_params(labelsize=12)
ax3.set_ylim(1, 12)

ax4.tick_params(labelsize=12)

ax5.set_ylabel('DSC', fontsize=15)
ax5.set_xlabel('Case', fontsize=15)
ax5.tick_params(labelsize=12)
ax5.set_ylim(0.84, 1.0)

ax6.set_xlabel('Case', fontsize=15)
ax6.tick_params(labelsize=12)

for axis in [ax2, ax4, ax6]:
    axis.yaxis.set_tick_params(labelbottom=True)
    
# plt.savefig('SWBE_boxplots_report.png', dpi=150, bbox_inches='tight')
